# %% [markdown]
# #### Aula 04 - Jinja2

# %% [markdown]
# ##### Import

# %%
import jinja2
import csv

# %% [markdown]
# ##### Definição das Variáveis Iniciais

# %%
source_file = 'switch-ports.csv'
interface_template_file = 'switch-interface-template.j2'
interface_configs=''

# %% [markdown]
# ##### Abrir o Arquivo

# %%
with open(interface_template_file) as f:
    interface_template = jinja2.Template(f.read(),keep_trailing_newline=True)
    
with open(source_file) as f:
    reader = csv.DictReader(f)
    for row in reader:
        interface_config = interface_template.render(
            interface = row['Interface'],
            vlan = row['Vlan'],
            host = row['Host'],
            connection = row['Connection']
        )
        interface_configs += interface_config

# %%
with open ('interface_configs.txt','w') as f:
    f.write(interface_configs)

# %%
config_set = interface_configs.split('\n')
print(config_set)
# Out:
# ['ï»¿! Configuracao Gerada via Jinja2 template', 'interface ethernet1/1', ' description Link to esxi-02 port nic3', ' switchport', ' switchport mode access', ' switchport access vlan 44', ' spanning-tree port type edge', ' no shutdown', ' !', '', 'ï»¿! Configuracao Gerada via Jinja2 template', 'interface ethernet1/2', ' description Link to srv-03 port eth1', ' switchport', ' switchport mode access', ' switchport access vlan 44', ' spanning-tree port type edge', ' no shutdown', ' !', '', 'ï»¿! Configuracao Gerada via Jinja2 template', 'interface ethernet1/3', ' description Link to lnx-02 port nic1', ' switchport', ' switchport mode access', ' switchport access vlan 35', ' spanning-tree port type edge', ' no shutdown', ' !', '', 'ï»¿! Configuracao Gerada via Jinja2 template', 'interface ethernet1/4', ' description Link to srv-01 port eth1', ' switchport', ' switchport mode access', ' switchport access vlan 44', ' spanning-tree port type edge', ' no shutdown', ' !', '', 'ï»¿! Configuracao Gerada via Jinja2 template', 'interface ethernet1/5', ' description Link to lnx-01 port nic1', ' switchport', ' switchport mode trunk', ' no shutdown', ' !', '', 'ï»¿! Configuracao Gerada via Jinja2 template', 'interface ethernet1/6', ' description Link to lnx-03 port nic1', ' switchport', ' switchport mode access', ' switchport access vlan 23', ' spanning-tree port type edge', ' no shutdown', ' !', '', 'ï»¿! Configuracao Gerada via Jinja2 template', 'interface ethernet1/7', ' description Link to lnx-02 port nic3', ' switchport', ' switchport mode trunk', ' no shutdown', ' !', '', 'ï»¿! Configuracao Gerada via Jinja2 template', 'interface ethernet1/8', ' description Link to lnx-02 port nic0', ' switchport', ' switchport mode access', ' switchport access vlan 44', ' spanning-tree port type edge', ' no shutdown', ' !', '', 'ï»¿! Configuracao Gerada via Jinja2 template', 'interface ethernet1/9', ' description Link to lnx-01 port nic1', ' switchport', ' switchport mode access', ' switchport access vlan 44', ' spanning-tree port type edge', ' no shutdown', ' !', '', 'ï»¿! Configuracao Gerada via Jinja2 template', 'interface ethernet1/10', ' description Link to lnx-03 port nic3', ' switchport', ' switchport mode access', ' switchport access vlan 23', ' spanning-tree port type edge', ' no shutdown', ' !', '', 'ï»¿! Configuracao Gerada via Jinja2 template', 'interface ethernet1/1', ' description Link to esxi-02 port nic3', ' switchport', ' switchport mode access', ' switchport access vlan 44', ' spanning-tree port type edge', ' no shutdown', ' !', 'ï»¿! Configuracao Gerada via Jinja2 template', 'interface ethernet1/2', ' description Link to srv-03 port eth1', ' switchport', ' switchport mode access', ' switchport access vlan 44', ' spanning-tree port type edge', ' no shutdown', ' !', 'ï»¿! Configuracao Gerada via Jinja2 template', 'interface ethernet1/3', ' description Link to lnx-02 port nic1', ' switchport', ' switchport mode access', ' switchport access vlan 35', ' spanning-tree port type edge', ' no shutdown', ' !', 'ï»¿! Configuracao Gerada via Jinja2 template', 'interface ethernet1/4', ' description Link to srv-01 port eth1', ' switchport', ' switchport mode access', ' switchport access vlan 44', ' spanning-tree port type edge', ' no shutdown', ' !', 'ï»¿! Configuracao Gerada via Jinja2 template', 'interface ethernet1/5', ' description Link to lnx-01 port nic1', ' switchport', ' switchport mode trunk', ' no shutdown', ' !', 'ï»¿! Configuracao Gerada via Jinja2 template', 'interface ethernet1/6', ' description Link to lnx-03 port nic1', ' switchport', ' switchport mode access', ' switchport access vlan 23', ' spanning-tree port type edge', ' no shutdown', ' !', 'ï»¿! Configuracao Gerada via Jinja2 template', 'interface ethernet1/7', ' description Link to lnx-02 port nic3', ' switchport', ' switchport mode trunk', ' no shutdown', ' !', 'ï»¿! Configuracao Gerada via Jinja2 template', 'interface ethernet1/8', ' description Link to lnx-02 port nic0', ' ...

# %%
from napalm import get_network_driver
with open('interface_configs.txt') as f:
    config_set = f.read().splitlines()
print(config_set)
# driver = get_network_driver('nxos_ssh')
# devices = ['sbx-nxos-mgmt.cisco.com']
# username = 'admin'
# passwd = 'Admin_1234!'
# device = driver('sbx-nxos-mgmt.cisco.com',username,passwd)
# device.open()
# dados = device.cli([config_set])

# # close the session with the device.
# device.close()
# print("Done.")
# Out:
# ['ï»¿! Configuracao Gerada via Jinja2 template', 'interface ethernet1/1', ' description Link to esxi-02 port nic3', ' switchport', ' switchport mode access', ' switchport access vlan 44', ' spanning-tree port type edge', ' no shutdown', ' !', '', 'ï»¿! Configuracao Gerada via Jinja2 template', 'interface ethernet1/2', ' description Link to srv-03 port eth1', ' switchport', ' switchport mode access', ' switchport access vlan 44', ' spanning-tree port type edge', ' no shutdown', ' !', '', 'ï»¿! Configuracao Gerada via Jinja2 template', 'interface ethernet1/3', ' description Link to lnx-02 port nic1', ' switchport', ' switchport mode access', ' switchport access vlan 35', ' spanning-tree port type edge', ' no shutdown', ' !', '', 'ï»¿! Configuracao Gerada via Jinja2 template', 'interface ethernet1/4', ' description Link to srv-01 port eth1', ' switchport', ' switchport mode access', ' switchport access vlan 44', ' spanning-tree port type edge', ' no shutdown', ' !', '', 'ï»¿! Configuracao Gerada via Jinja2 template', 'interface ethernet1/5', ' description Link to lnx-01 port nic1', ' switchport', ' switchport mode trunk', ' no shutdown', ' !', '', 'ï»¿! Configuracao Gerada via Jinja2 template', 'interface ethernet1/6', ' description Link to lnx-03 port nic1', ' switchport', ' switchport mode access', ' switchport access vlan 23', ' spanning-tree port type edge', ' no shutdown', ' !', '', 'ï»¿! Configuracao Gerada via Jinja2 template', 'interface ethernet1/7', ' description Link to lnx-02 port nic3', ' switchport', ' switchport mode trunk', ' no shutdown', ' !', '', 'ï»¿! Configuracao Gerada via Jinja2 template', 'interface ethernet1/8', ' description Link to lnx-02 port nic0', ' switchport', ' switchport mode access', ' switchport access vlan 44', ' spanning-tree port type edge', ' no shutdown', ' !', '', 'ï»¿! Configuracao Gerada via Jinja2 template', 'interface ethernet1/9', ' description Link to lnx-01 port nic1', ' switchport', ' switchport mode access', ' switchport access vlan 44', ' spanning-tree port type edge', ' no shutdown', ' !', '', 'ï»¿! Configuracao Gerada via Jinja2 template', 'interface ethernet1/10', ' description Link to lnx-03 port nic3', ' switchport', ' switchport mode access', ' switchport access vlan 23', ' spanning-tree port type edge', ' no shutdown', ' !', '', 'ï»¿! Configuracao Gerada via Jinja2 template', 'interface ethernet1/1', ' description Link to esxi-02 port nic3', ' switchport', ' switchport mode access', ' switchport access vlan 44', ' spanning-tree port type edge', ' no shutdown', ' !', 'ï»¿! Configuracao Gerada via Jinja2 template', 'interface ethernet1/2', ' description Link to srv-03 port eth1', ' switchport', ' switchport mode access', ' switchport access vlan 44', ' spanning-tree port type edge', ' no shutdown', ' !', 'ï»¿! Configuracao Gerada via Jinja2 template', 'interface ethernet1/3', ' description Link to lnx-02 port nic1', ' switchport', ' switchport mode access', ' switchport access vlan 35', ' spanning-tree port type edge', ' no shutdown', ' !', 'ï»¿! Configuracao Gerada via Jinja2 template', 'interface ethernet1/4', ' description Link to srv-01 port eth1', ' switchport', ' switchport mode access', ' switchport access vlan 44', ' spanning-tree port type edge', ' no shutdown', ' !', 'ï»¿! Configuracao Gerada via Jinja2 template', 'interface ethernet1/5', ' description Link to lnx-01 port nic1', ' switchport', ' switchport mode trunk', ' no shutdown', ' !', 'ï»¿! Configuracao Gerada via Jinja2 template', 'interface ethernet1/6', ' description Link to lnx-03 port nic1', ' switchport', ' switchport mode access', ' switchport access vlan 23', ' spanning-tree port type edge', ' no shutdown', ' !', 'ï»¿! Configuracao Gerada via Jinja2 template', 'interface ethernet1/7', ' description Link to lnx-02 port nic3', ' switchport', ' switchport mode trunk', ' no shutdown', ' !', 'ï»¿! Configuracao Gerada via Jinja2 template', 'interface ethernet1/8', ' description Link to lnx-02 port nic0', ' ...
